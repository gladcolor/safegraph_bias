# %%
import pandas as pd

# %%
ACS_2020_df = pd.read_csv(r"F:\Research\Safegraph_bias\ACS2020.csv")
ACS_2019_df = pd.read_csv(r"F:\Research\Safegraph_bias\ACS2019.csv")
ACS_2021_df = pd.read_csv(r"F:\Research\Safegraph_bias\ACS2021.csv")

ACS_2020_df
ACS_2021_df
# Out:
#             Geo_FIPS                                          Geo_QName  \
# 0        10010201001  Block Group 1, Census Tract 201, Autauga Count...
# 1        10010201002  Block Group 2, Census Tract 201, Autauga Count...
# 2        10010202001  Block Group 1, Census Tract 202, Autauga Count...
# 3        10010202002  Block Group 2, Census Tract 202, Autauga Count...
# 4        10010203001  Block Group 1, Census Tract 203, Autauga Count...
# ...              ...                                                ...
# 242330  721537506011  Block Group 1, Census Tract 7506.01, Yauco Mun...
# 242331  721537506012  Block Group 2, Census Tract 7506.01, Yauco Mun...
# 242332  721537506013  Block Group 3, Census Tract 7506.01, Yauco Mun...
# 242333  721537506021  Block Group 1, Census Tract 7506.02, Yauco Mun...
# 242334  721537506022  Block Group 2, Census Tract 7506.02, Yauco Mun...
#
#        Geo_FILEID Geo_STUSAB  Geo_SUMLEV  Geo_GEOCOMP  Geo_LOGRECNO  Geo_US  \
# ...

# %%
len(ACS_2021_df.merge(ACS_2019_df, on='Geo_FIPS')), len(ACS_2019_df.merge(ACS_2021_df, on='Geo_FIPS'))
# Out:
# (173585, 173585)

# %%
ACS_2019_df
# Out:
#             Geo_FIPS            Geo_GEOID       Geo_NAME  \
# 0        10010201001  15000US010010201001  Block Group 1
# 1        10010201002  15000US010010201002  Block Group 2
# 2        10010202001  15000US010010202001  Block Group 1
# 3        10010202002  15000US010010202002  Block Group 2
# 4        10010203001  15000US010010203001  Block Group 1
# ...              ...                  ...            ...
# 220328  721537506011  15000US721537506011  Block Group 1
# 220329  721537506012  15000US721537506012  Block Group 2
# 220330  721537506013  15000US721537506013  Block Group 3
# 220331  721537506021  15000US721537506021  Block Group 1
# 220332  721537506022  15000US721537506022  Block Group 2
#
#                                                 Geo_QName Geo_STUSAB  \
# 0       Block Group 1, Census Tract 201, Autauga Count...         al
# 1       Block Group 2, Census Tract 201, Autauga Count...         al
# 2       Block Group 1, Census Tract 202, Autauga Count...         al
# ...
